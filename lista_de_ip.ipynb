# %% [markdown]
# <a href="https://colab.research.google.com/github/Genesis5690/lista_de_ip/blob/main/lista_de_ip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
 
red = input("Introduce una IP (por ejemplo 192.168.1): ")
if red =="":
    red = "192.168.1"
rangoInicial = int(input("Introduzca el rango inicial (por ejemplo 1): "))
rangoFinal = int(input("Introduzca el rango final (por ejemplo 250): "))
 
# Obtenemos el sistema operativo, nt = windows, posix = Linux
so = os.name
 
if rangoInicial > rangoFinal:
    print("Debe indicar un rango inicial inferior al rango final")
else:
    listaIP =[] # Lista de IP que responden al ping
    for i in range(rangoInicial, rangoFinal, 1): # Recorremos el rango de IP indicado
        ipEquipo = red + "." + str(i)
        print("Haciendo ping a IP " + ipEquipo, end=" ")
        if (so == "nt"):
            rep = os.system("ping -n 1 " + ipEquipo + " > 1")
        else:
            rep = os.system("ping -c 1 " + ipEquipo + " > 1")
        if rep == 0:
            listaIP.append(ipEquipo)
            print("[OK]")
        else:
            print("[No responde]")
    
    print("/n Las IP que han respondido al ping: " + str(len(listaIP)))
    for i in range(len(listaIP)):
        print(listaIP[i])
# Out:
# Introduzca una red (por ejemplo 192.168.1): 192.2.2.2
# Introduzca el rango inicial (por ejemplo 1): 5
# Introduzca el rango final (por ejemplo 250): 240
# Haciendo ping a IP 192.2.2.2.5 [No responde]
# Haciendo ping a IP 192.2.2.2.6 [No responde]
# Haciendo ping a IP 192.2.2.2.7 [No responde]
# Haciendo ping a IP 192.2.2.2.8 [No responde]
# Haciendo ping a IP 192.2.2.2.9 [No responde]
# Haciendo ping a IP 192.2.2.2.10 [No responde]
# Haciendo ping a IP 192.2.2.2.11 [No responde]
# Haciendo ping a IP 192.2.2.2.12 [No responde]
# Haciendo ping a IP 192.2.2.2.13 [No responde]
# Haciendo ping a IP 192.2.2.2.14 [No responde]
# Haciendo ping a IP 192.2.2.2.15 [No responde]
# Haciendo ping a IP 192.2.2.2.16 [No responde]
# Haciendo ping a IP 192.2.2.2.17 [No responde]
# Haciendo ping a IP 192.2.2.2.18 [No responde]
# Haciendo ping a IP 192.2.2.2.19 [No responde]
# Haciendo ping a IP 192.2.2.2.20 [No responde]
# Haciendo ping a IP 192.2.2.2.21 [No responde]
# ...
